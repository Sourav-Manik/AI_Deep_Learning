# %% [markdown]
# <a href="https://colab.research.google.com/github/Sourav-Manik/AI_Deep_Learning/blob/main/Language_Modelling_Next_Word_Prediction_Text_Generation_(Imported_Dataset).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##1. Import Necessary libraries##

# %%
from keras.models import Sequential
from keras.layers import Embedding, LSTM, Dense, Dropout
from keras.preprocessing.text import Tokenizer
import requests
import pandas as pd

# %% [markdown]
# ##2. Import Data##

# %%
#data = requests.get('https://gutenberg.org/cache/epub/69364/pg69364.txt')
#data = pd.read_csv('/content/book.txt')

fileObject = open("/content/book.txt", "r")
data = fileObject.read()
print(data)
# Out:
# ﻿The Project Gutenberg eBook of A little girl's cookery book, by
# Caroline French Benton
#
# This eBook is for the use of anyone anywhere in the United States and
# most other parts of the world at no cost and with almost no restrictions
# whatsoever. You may copy it, give it away or re-use it under the terms
# of the Project Gutenberg License included with this eBook or online at
# www.gutenberg.org. If you are not located in the United States, you
# will have to check the laws of the country where you are located before
# using this eBook.
#
# Title: A little girl's cookery book
#
# Authors: Caroline French Benton
#          Mary Florence Hodge
#
# Release Date: November 15, 2022 [eBook #69364]
#
# Language: English
#
# Produced by: David E. Brown, and the Online Distributed Proofreading
#              Team at https://www.pgdp.net (This file was produced from
#              images generously made available by The Internet Archive)
#
# ...

# %% [markdown]
# ##3. Data Preparation##

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts([data])
encoded_data = tokenizer.texts_to_sequences(texts = [data])[0]

# %%
min(encoded_data), max(encoded_data)
# Out:
# (1, 2374)

# %%
vocab = len(set(encoded_data)) #getting unique value by using sets
vocab
# Out:
# 2374

# %% [markdown]
# ###3.1 Create sequence of words to fit the model with one as input and one word as output.###

# %%
len(encoded_data)
# Out:
# 26846

# %%
sequences = []

for i in range(1,len(encoded_data)):
  sequence = encoded_data[i-1:i+1]
  sequences.append(sequence)
print('Total number of sequences : ',len(sequences))
# Out:
# Total number of sequences :  26845

# %%
import numpy as np
sequences = np.array(sequences)
X = sequences[:,0] #taking only input data
y = sequences[:,1]

# %%
X[:5]
# Out:
# array([1408,   45,   41,  313,    3])

# %%
y[:5]
# Out:
# array([ 45,  41, 313,   3,   4])

# %% [markdown]
# ##4. Model Building##

# %%
vocab = vocab + 1 # we have to add 1 as it is required for below.
model =Sequential()
model.add(Embedding(input_dim=vocab,output_dim = 40,input_length=1)) #output dimension is set as 10. It means that for 1 input it will have 10 embeddings
model.add(LSTM(units = 50,dropout = 0.15))
model.add(Dense(units=50, activation = 'tanh'))
model.add(Dropout(0.40))
model.add(Dense(units = vocab,activation = 'softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding (Embedding)       (None, 1, 40)             95000
#
#  lstm (LSTM)                 (None, 50)                18200
#
#  dense (Dense)               (None, 50)                2550
#
#  dropout (Dropout)           (None, 50)                0
#
#  dense_1 (Dense)             (None, 2375)              121125
#
# ...
# Total params: 236,875
# Trainable params: 236,875
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='Adam', loss ='sparse_categorical_crossentropy' ,metrics = 'accuracy')

# %% [markdown]
# ##5. Model Training##

# %%
model.fit(x=X,y=y,epochs=100)
# Out:
# Epoch 1/100
# 839/839 [==============================] - 17s 17ms/step - loss: 6.1474 - accuracy: 0.0593
# Epoch 2/100
# 839/839 [==============================] - 8s 10ms/step - loss: 5.8387 - accuracy: 0.0602
# Epoch 3/100
# 839/839 [==============================] - 8s 10ms/step - loss: 5.7889 - accuracy: 0.0673
# Epoch 4/100
# 839/839 [==============================] - 9s 11ms/step - loss: 5.6296 - accuracy: 0.1052
# Epoch 5/100
# 839/839 [==============================] - 8s 10ms/step - loss: 5.3914 - accuracy: 0.1363
# Epoch 6/100
# 839/839 [==============================] - 8s 10ms/step - loss: 5.2492 - accuracy: 0.1460
# Epoch 7/100
# 839/839 [==============================] - 8s 9ms/step - loss: 5.1304 - accuracy: 0.1578
# Epoch 8/100
# 839/839 [==============================] - 8s 9ms/step - loss: 5.0314 - accuracy: 0.1667
# Epoch 9/100
# 839/839 [==============================] - 8s 9ms/step - loss: 4.9356 - accuracy: 0.1753
# Epoch 10/100
# ...

# %% [markdown]
# ##6. Model Prediction##

# %% [markdown]
# Generate new words based on the previous word

# %%
tokenizer.word_index.items()
# Out:
# dict_items([('the', 1), ('and', 2), ('of', 3), ('a', 4), ('in', 5), ('it', 6), ('with', 7), ('put', 8), ('to', 9), ('1', 10), ('or', 11), ('you', 12), ('on', 13), ('is', 14), ('them', 15), ('then', 16), ('sugar', 17), ('this', 18), ('for', 19), ('cup', 20), ('till', 21), ('eggs', 22), ('butter', 23), ('as', 24), ('salt', 25), ('into', 26), ('little', 27), ('all', 28), ('one', 29), ('water', 30), ('teaspoonful', 31), ('cream', 32), ('very', 33), ('not', 34), ('milk', 35), ('half', 36), ('flour', 37), ('over', 38), ('when', 39), ('hot', 40), ('gutenberg', 41), ('add', 42), ('are', 43), ('make', 44), ('project', 45), ('if', 46), ('take', 47), ('two', 48), ('out', 49), ('½', 50), ('be', 51), ('egg', 52), ('dish', 53), ('cook', 54), ('stir', 55), ('sauce', 56), ('by', 57), ('cold', 58), ('cut', 59), ('they', 60), ('2', 61), ('brown', 62), ('have', 63), ('pepper', 64), ('mix', 65), ('will', 66), ('well', 67), ('small', 68), ('beat', 69), ('she', 70), ('up', 71), ('from', 72), ('at', 73), (
# ...

# %%
#from numpy.core.multiarray import result_type
def generate_text_sequence(model,tokenizer,enter_text,n_pred):
  in_text, result = enter_text,enter_text

  for _ in range(n_pred):
      encoded_data = tokenizer.texts_to_sequences(texts = [data])[0]
      encoded_data = np.array(encoded_data)

      y_pred = model.predict(encoded_data)

      #mapping the predicted word index to the word
      predicted_word = ''
      for word,index in tokenizer.word_index.items():
        if index == y_pred.all():
           predicted_word = word
           break

      in_text, result =predicted_word, result + '' + predicted_word
  return result

# %%
generate_text_sequence(model,tokenizer, 'virus',1)
# Out:
# 839/839 [==============================] - 4s 4ms/step
# 'virusthe'
