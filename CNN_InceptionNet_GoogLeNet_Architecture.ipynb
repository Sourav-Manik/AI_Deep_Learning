# %% [markdown]
# <a href="https://colab.research.google.com/github/Sourav-Manik/AI_Deep_Learning/blob/main/CNN_InceptionNet_GoogLeNet_Architecture.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**I. Introduction**

# %% [markdown]
# GoogLeNet is a deep convolutional neural network that was proposed by Szegedy et al. [1]. This network won the ImageNet Large-Scale Visual Recognition Challenge 2014 (ILSVRC-2014) where 92.3% classification performance was achieved. In particular, this model was designed in a special architecture that allows for increasing the depth and width of the network but keeping the computing resource.
#
# The VGG model has in total 22 layers and it is composed of 9 Inception blocks. Each Inception block consists of four parallel paths at which convolution layers with different kernel sizes are applied [Figure 1]:
#
# *The first path uses a convolutional layer with a window size of 1 × 1.
#
# *In the second and the third paths, a convolutional layer of size 1 × 1 is used before applying two expensive 3 × 3 and 5 × 5 convolutions. The 1×1 convolution helps to reduce the number of filter channels, thus reducing the model complexity.
#
# *The fourth path uses a max-pooling layer to reduce the resolution of the input, and it is followed by a 1 × 1 convolutional layer to reduce the dimension.
#
# These four paths use appropriate padding so that the input and output have the same size. The concatenation of these four paths allows scanning the input in different resolutions. Especially, the model complexity is minimized thanks to the application of a 1 × 1 convolutional layer in each path.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# In summary:
#
# *The input size image is 224 × 224.
#
# *There are nine Inception blocks in this network.
#
# *There are four max-pooling layers outside the Inception blocks, in which two layers are located between blocks 3–4 and block 7–8. These max-pooling layers help to reduce the size of the input data, thus reduce the model complexity as well as the computational cost.
#
# *This network inherits the idea of using an average pooling layer from NiN, which helps to improve the model performance and reduce overfitting.
#
# *A dropout layer (with 40%) is utilized before the linear layer. This is also an efficient regularization method to reduce the overfitting phenomena. The output layer uses the softmax activation function to give 1000 outputs which are corresponding to the number of categories in the ImageNet dataset.
#
# Besides, some extra networks are added on the side, which encourages discrimination in the lower stages in the classifier, increases the gradient signal that gets backpropagation, and provides additional regularization. The structure of these networks includes:
#
# *An average pooling layer with pooling size 5 × 5 and stride 3.
#
# *A 1 × 1 convolutional layer with 128 filters for dimensional reduction and a rectified linear activation.
#
# *A fully connected layer with 1024 units and a rectified linear activation.
#
# *A dropout with a ratio of 70% of outputs.
#
# *An output layer that used a softmax activation function to classify the object into one of 1000 classes.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #II. Implementation of GoogLeNet on Keras

# %% [markdown]
# Firstly, we need to import some necessary libraries:

# %%
from keras.models import Model
from keras.layers import Input, Conv2D, MaxPooling2D, AveragePooling2D, Flatten, GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.layers import concatenate

from keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator
import numpy as np

# %% [markdown]
# create an Inception block

# %%
def Inception_block(input_layer, f1, f2_conv1, f2_conv3, f3_conv1, f3_conv5, f4): 
  # Input: 
  # - f1: number of filters of the 1x1 convolutional layer in the first path
  # - f2_conv1, f2_conv3 are number of filters corresponding to the 1x1 and 3x3 convolutional layers in the second path
  # - f3_conv1, f3_conv5 are the number of filters corresponding to the 1x1 and 5x5  convolutional layer in the third path
  # - f4: number of filters of the 1x1 convolutional layer in the fourth path

  # 1st path:
  path1 = Conv2D(filters=f1, kernel_size = (1,1), padding = 'same', activation = 'relu')(input_layer)

  # 2nd path
  path2 = Conv2D(filters = f2_conv1, kernel_size = (1,1), padding = 'same', activation = 'relu')(input_layer)
  path2 = Conv2D(filters = f2_conv3, kernel_size = (3,3), padding = 'same', activation = 'relu')(path2)

  # 3rd path
  path3 = Conv2D(filters = f3_conv1, kernel_size = (1,1), padding = 'same', activation = 'relu')(input_layer)
  path3 = Conv2D(filters = f3_conv5, kernel_size = (5,5), padding = 'same', activation = 'relu')(path3)

  # 4th path
  path4 = MaxPooling2D((3,3), strides= (1,1), padding = 'same')(input_layer)
  path4 = Conv2D(filters = f4, kernel_size = (1,1), padding = 'same', activation = 'relu')(path4)

  output_layer = concatenate([path1, path2, path3, path4], axis = -1)

  return output_layer

# %% [markdown]
# Function to implement the GoogLeNet model:

# %%
def GoogLeNet():
  # input layer 
  input_layer = Input(shape = (224, 224, 3))

  # convolutional layer: filters = 64, kernel_size = (7,7), strides = 2
  X = Conv2D(filters = 64, kernel_size = (7,7), strides = 2, padding = 'valid', activation = 'relu')(input_layer)

  # max-pooling layer: pool_size = (3,3), strides = 2
  X = MaxPooling2D(pool_size = (3,3), strides = 2)(X)

  # convolutional layer: filters = 64, strides = 1
  X = Conv2D(filters = 64, kernel_size = (1,1), strides = 1, padding = 'same', activation = 'relu')(X)

  # convolutional layer: filters = 192, kernel_size = (3,3)
  X = Conv2D(filters = 192, kernel_size = (3,3), padding = 'same', activation = 'relu')(X)

  # max-pooling layer: pool_size = (3,3), strides = 2
  X = MaxPooling2D(pool_size= (3,3), strides = 2)(X)

  # 1st Inception block
  X = Inception_block(X, f1 = 64, f2_conv1 = 96, f2_conv3 = 128, f3_conv1 = 16, f3_conv5 = 32, f4 = 32)

  # 2nd Inception block
  X = Inception_block(X, f1 = 128, f2_conv1 = 128, f2_conv3 = 192, f3_conv1 = 32, f3_conv5 = 96, f4 = 64)

  # max-pooling layer: pool_size = (3,3), strides = 2
  X = MaxPooling2D(pool_size= (3,3), strides = 2)(X)

  # 3rd Inception block
  X = Inception_block(X, f1 = 192, f2_conv1 = 96, f2_conv3 = 208, f3_conv1 = 16, f3_conv5 = 48, f4 = 64)

  # Extra network 1:
  X1 = AveragePooling2D(pool_size = (5,5), strides = 3)(X)
  X1 = Conv2D(filters = 128, kernel_size = (1,1), padding = 'same', activation = 'relu')(X1)
  X1 = Flatten()(X1)
  X1 = Dense(1024, activation = 'relu')(X1)
  X1 = Dropout(0.7)(X1)
  X1 = Dense(4, activation = 'softmax')(X1) #Provide the number of output .i.e in this case it is a 4 class classification. 

  
  # 4th Inception block
  X = Inception_block(X, f1 = 160, f2_conv1 = 112, f2_conv3 = 224, f3_conv1 = 24, f3_conv5 = 64, f4 = 64)

  # 5th Inception block
  X = Inception_block(X, f1 = 128, f2_conv1 = 128, f2_conv3 = 256, f3_conv1 = 24, f3_conv5 = 64, f4 = 64)

  # 6th Inception block
  X = Inception_block(X, f1 = 112, f2_conv1 = 144, f2_conv3 = 288, f3_conv1 = 32, f3_conv5 = 64, f4 = 64)

  # Extra network 2:
  X2 = AveragePooling2D(pool_size = (5,5), strides = 3)(X)
  X2 = Conv2D(filters = 128, kernel_size = (1,1), padding = 'same', activation = 'relu')(X2)
  X2 = Flatten()(X2)
  X2 = Dense(1024, activation = 'relu')(X2)
  X2 = Dropout(0.7)(X2)
  X2 = Dense(4, activation = 'softmax')(X2) #Provide the number of output .i.e in this case it is a 4 class classification. 
  
  
  # 7th Inception block
  X = Inception_block(X, f1 = 256, f2_conv1 = 160, f2_conv3 = 320, f3_conv1 = 32, 
                      f3_conv5 = 128, f4 = 128)

  # max-pooling layer: pool_size = (3,3), strides = 2
  X = MaxPooling2D(pool_size = (3,3), strides = 2)(X)

  # 8th Inception block
  X = Inception_block(X, f1 = 256, f2_conv1 = 160, f2_conv3 = 320, f3_conv1 = 32, f3_conv5 = 128, f4 = 128)

  # 9th Inception block
  X = Inception_block(X, f1 = 384, f2_conv1 = 192, f2_conv3 = 384, f3_conv1 = 48, f3_conv5 = 128, f4 = 128)

  # Global Average pooling layer 
  X = GlobalAveragePooling2D(name = 'GAPL')(X)

  # Dropoutlayer 
  X = Dropout(0.4)(X)

  # output layer 
  X = Dense(4, activation = 'softmax')(X) #Provide the number of output .i.e in this case it is a 4 class classification. 
  
  # model
  model = Model(input_layer, [X, X1, X2], name = 'GoogLeNet') #X1 and X2 are optional as both are extra networks.

  return model

# %%
model = GoogLeNet()

# %%
model.summary()
# Out:
# Model: "GoogLeNet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 109, 109, 64  9472        ['input_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 54, 54, 64)   0           ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 54, 54, 64)   4160        ['max_pooling2d[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 54, 54, 192)  110784      ['conv2d_1[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 26, 26, 192)  0          ['conv2d_2[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 26, 26, 96)   18528       ['max_pooling2d_1[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 26, 26, 16)   3088        ['max_pooling2d_1[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 26, 26, 192)  0          ['max_pooling2d_1[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 26, 26, 64)   12352       ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 26, 26, 128)  110720      ['conv2d_4[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 26, 26, 32)   12832       ['conv2d_6[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 26, 26, 32)   6176        ['max_pooling2d_2[0][0]']
#
#  concatenate (Concatenate)      (None, 26, 26, 256)  0           ['conv2d_3[0][0]',
#                                                                   'conv2d_5[0][0]',
#                                                                   'conv2d_7[0][0]',
#                                                                   'conv2d_8[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 26, 26, 128)  32896       ['concatenate[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 26, 26, 32)   8224        ['concatenate[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 26, 26, 256)  0          ['concatenate[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 26, 26, 128)  32896       ['concatenate[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 26, 26, 192)  221376      ['conv2d_10[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 26, 26, 96)   76896       ['conv2d_12[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 26, 26, 64)   16448       ['max_pooling2d_3[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 26, 26, 480)  0           ['conv2d_9[0][0]',
#                                                                   'conv2d_11[0][0]',
#                                                                   'conv2d_13[0][0]',
#                                                                   'conv2d_14[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 12, 12, 480)  0          ['concatenate_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 12, 12, 96)   46176       ['max_pooling2d_4[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 12, 12, 16)   7696        ['max_pooling2d_4[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 12, 12, 480)  0          ['max_pooling2d_4[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 12, 12, 192)  92352       ['max_pooling2d_4[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 12, 12, 208)  179920      ['conv2d_16[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 12, 12, 48)   19248       ['conv2d_18[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 12, 12, 64)   30784       ['max_pooling2d_5[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 12, 12, 512)  0           ['conv2d_15[0][0]',
#                                                                   'conv2d_17[0][0]',
#                                                                   'conv2d_19[0][0]',
#                                                                   'conv2d_20[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 12, 12, 112)  57456       ['concatenate_2[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 12, 12, 24)   12312       ['concatenate_2[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 12, 12, 512)  0          ['concatenate_2[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 12, 12, 160)  82080       ['concatenate_2[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 12, 12, 224)  226016      ['conv2d_23[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 12, 12, 64)   38464       ['conv2d_25[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 12, 12, 64)   32832       ['max_pooling2d_6[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 12, 12, 512)  0           ['conv2d_22[0][0]',
#                                                                   'conv2d_24[0][0]',
#                                                                   'conv2d_26[0][0]',
#                                                                   'conv2d_27[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 12, 12, 128)  65664       ['concatenate_3[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 12, 12, 24)   12312       ['concatenate_3[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 12, 12, 512)  0          ['concatenate_3[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 12, 12, 128)  65664       ['concatenate_3[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 12, 12, 256)  295168      ['conv2d_29[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 12, 12, 64)   38464       ['conv2d_31[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 12, 12, 64)   32832       ['max_pooling2d_7[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 12, 12, 512)  0           ['conv2d_28[0][0]',
#                                                                   'conv2d_30[0][0]',
#                                                                   'conv2d_32[0][0]',
#                                                                   'conv2d_33[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 12, 12, 144)  73872       ['concatenate_4[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 12, 12, 32)   16416       ['concatenate_4[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 12, 12, 512)  0          ['concatenate_4[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 12, 12, 112)  57456       ['concatenate_4[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 12, 12, 288)  373536      ['conv2d_35[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 12, 12, 64)   51264       ['conv2d_37[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 12, 12, 64)   32832       ['max_pooling2d_8[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 12, 12, 528)  0           ['conv2d_34[0][0]',
#                                                                   'conv2d_36[0][0]',
#                                                                   'conv2d_38[0][0]',
#                                                                   'conv2d_39[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 12, 12, 160)  84640       ['concatenate_5[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 12, 12, 32)   16928       ['concatenate_5[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 12, 12, 528)  0          ['concatenate_5[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 12, 12, 256)  135424      ['concatenate_5[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 12, 12, 320)  461120      ['conv2d_42[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 12, 12, 128)  102528      ['conv2d_44[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 12, 12, 128)  67712       ['max_pooling2d_9[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 12, 12, 832)  0           ['conv2d_41[0][0]',
#                                                                   'conv2d_43[0][0]',
#                                                                   'conv2d_45[0][0]',
#                                                                   'conv2d_46[0][0]']
#
#  max_pooling2d_10 (MaxPooling2D  (None, 5, 5, 832)   0           ['concatenate_6[0][0]']
#  )
#
#  conv2d_48 (Conv2D)             (None, 5, 5, 160)    133280      ['max_pooling2d_10[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 5, 5, 32)     26656       ['max_pooling2d_10[0][0]']
#
#  max_pooling2d_11 (MaxPooling2D  (None, 5, 5, 832)   0           ['max_pooling2d_10[0][0]']
#  )
#
#  conv2d_47 (Conv2D)             (None, 5, 5, 256)    213248      ['max_pooling2d_10[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 5, 5, 320)    461120      ['conv2d_48[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 5, 5, 128)    102528      ['conv2d_50[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 5, 5, 128)    106624      ['max_pooling2d_11[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 5, 5, 832)    0           ['conv2d_47[0][0]',
#                                                                   'conv2d_49[0][0]',
#                                                                   'conv2d_51[0][0]',
#                                                                   'conv2d_52[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 5, 5, 192)    159936      ['concatenate_7[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 5, 5, 48)     39984       ['concatenate_7[0][0]']
#
#  max_pooling2d_12 (MaxPooling2D  (None, 5, 5, 832)   0           ['concatenate_7[0][0]']
#  )
#
#  average_pooling2d (AveragePool  (None, 3, 3, 512)   0           ['concatenate_2[0][0]']
#  ing2D)
#
#  average_pooling2d_1 (AveragePo  (None, 3, 3, 528)   0           ['concatenate_5[0][0]']
#  oling2D)
#
#  conv2d_53 (Conv2D)             (None, 5, 5, 384)    319872      ['concatenate_7[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 5, 5, 384)    663936      ['conv2d_54[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 5, 5, 128)    153728      ['conv2d_56[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 5, 5, 128)    106624      ['max_pooling2d_12[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 3, 3, 128)    65664       ['average_pooling2d[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 3, 3, 128)    67712       ['average_pooling2d_1[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 5, 5, 1024)   0           ['conv2d_53[0][0]',
#                                                                   'conv2d_55[0][0]',
#                                                                   'conv2d_57[0][0]',
#                                                                   'conv2d_58[0][0]']
#
#  flatten (Flatten)              (None, 1152)         0           ['conv2d_21[0][0]']
#
#  flatten_1 (Flatten)            (None, 1152)         0           ['conv2d_40[0][0]']
#
#  GAPL (GlobalAveragePooling2D)  (None, 1024)         0           ['concatenate_8[0][0]']
#
#  dense (Dense)                  (None, 1024)         1180672     ['flatten[0][0]']
#
#  dense_2 (Dense)                (None, 1024)         1180672     ['flatten_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 1024)         0           ['GAPL[0][0]']
#
#  dropout (Dropout)              (None, 1024)         0           ['dense[0][0]']
#
#  dropout_1 (Dropout)            (None, 1024)         0           ['dense_2[0][0]']
#
#  dense_4 (Dense)                (None, 4)            4100        ['dropout_2[0][0]']
#
#  dense_1 (Dense)                (None, 4)            4100        ['dropout[0][0]']
#
#  dense_3 (Dense)                (None, 4)            4100        ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 8,480,572
# Trainable params: 8,480,572
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
trdata = ImageDataGenerator()
train_data = trdata.flow_from_directory(directory='/content/drive/MyDrive/AI/CNN_train_test_img/train_data',target_size=(224,224))

tsdata = ImageDataGenerator()
test_data = tsdata.flow_from_directory(directory='/content/drive/MyDrive/AI/CNN_train_test_img/test_data',target_size=(224,224))
# Out:
# Found 40 images belonging to 4 classes.
# Found 16 images belonging to 4 classes.

# %%
train_data.class_indices
# Out:
# {'Messi': 0, 'Modi': 1, 'Ritik': 2, 'Virat_Kholi': 3}

# %%
test_data.image_shape
# Out:
# (224, 224, 3)

# %%
model.compile(optimizer='adam',loss= 'categorical_crossentropy',metrics='accuracy')

# %%
model.fit(train_data,epochs = 50, verbose=1,validation_data = train_data,validation_steps=5)
# Out:
# Epoch 1/50
# 2/2 [==============================] - ETA: 0s - loss: 23.6912 - dense_4_loss: 5.5755 - dense_1_loss: 13.3864 - dense_3_loss: 4.7293 - dense_4_accuracy: 0.2250 - dense_1_accuracy: 0.2500 - dense_3_accuracy: 0.2000
# WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 5 batches). You may need to use the repeat() function when building your dataset.
# 2/2 [==============================] - 15s 5s/step - loss: 23.6912 - dense_4_loss: 5.5755 - dense_1_loss: 13.3864 - dense_3_loss: 4.7293 - dense_4_accuracy: 0.2250 - dense_1_accuracy: 0.2500 - dense_3_accuracy: 0.2000 - val_loss: 7.4168 - val_dense_4_loss: 2.5703 - val_dense_1_loss: 3.3685 - val_dense_3_loss: 1.4780 - val_dense_4_accuracy: 0.2500 - val_dense_1_accuracy: 0.2500 - val_dense_3_accuracy: 0.2500
# Epoch 2/50
# 2/2 [==============================] - 0s 238ms/step - loss: 6.4064 - dense_4_loss: 1.6242 - dense_1_loss: 3.0328 - dense_3_loss: 1.7494 - dense_4_accuracy: 0.2750 - dense_1_accuracy: 0.3250 - dense_3_accuracy: 0.2250
# Epoch 3/50
# 2/2 [==============================] - 0s 55ms/step - loss: 4.6337 - dense_4_loss: 1.4282 - dense_1_loss: 1.8141 - dense_3_loss: 1.3914 - dense_4_accuracy: 0.3500 - dense_1_accuracy: 0.3000 - dense_3_accuracy: 0.3250
# Epoch 4/50
# 2/2 [==============================] - 0s 252ms/step - loss: 5.6758 - dense_4_loss: 1.5136 - dense_1_loss: 2.4581 - dense_3_loss: 1.7040 - dense_4_accuracy: 0.2000 - dense_1_accuracy: 0.1750 - dense_3_accuracy: 0.1500
# Epoch 5/50
# 2/2 [==============================] - 0s 51ms/step - loss: 4.4219 - dense_4_loss: 1.4124 - dense_1_loss: 1.6247 - dense_3_loss: 1.3848 - dense_4_accuracy: 0.2500 - dense_1_accuracy: 0.2250 - dense_3_accuracy: 0.3250
# Epoch 6/50
# 2/2 [==============================] - 0s 52ms/step - loss: 4.2188 - dense_4_loss: 1.3924 - dense_1_loss: 1.4516 - dense_3_loss: 1.3748 - dense_4_accuracy: 0.3000 - dense_1_accuracy: 0.2500 - dense_3_accuracy: 0.4000
# Epoch 7/50
# 2/2 [==============================] - 0s 242ms/step - loss: 4.1857 - dense_4_loss: 1.3827 - dense_1_loss: 1.3817 - dense_3_loss: 1.4212 - dense_4_accuracy: 0.2500 - dense_1_accuracy: 0.2250 - dense_3_accuracy: 0.2750
# Epoch 8/50
# 2/2 [==============================] - 0s 50ms/step - loss: 4.1680 - dense_4_loss: 1.3874 - dense_1_loss: 1.4046 - dense_3_loss: 1.3760 - dense_4_accuracy: 0.3750 - dense_1_accuracy: 0.3250 - dense_3_accuracy: 0.3500
# Epoch 9/50
# 2/2 [==============================] - 0s 50ms/step - loss: 4.1836 - dense_4_loss: 1.3675 - dense_1_loss: 1.4067 - dense_3_loss: 1.4094 - dense_4_accuracy: 0.2750 - dense_1_accuracy: 0.3000 - dense_3_accuracy: 0.2500
# Epoch 10/50
# 2/2 [==============================] - 0s 54ms/step - loss: 4.1495 - dense_4_loss: 1.3903 - dense_1_loss: 1.4098 - dense_3_loss: 1.3495 - dense_4_accuracy: 0.2000 - dense_1_accuracy: 0.2250 - dense_3_accuracy: 0.3500
# Epoch 11/50
# 2/2 [==============================] - 0s 50ms/step - loss: 4.1885 - dense_4_loss: 1.3691 - dense_1_loss: 1.3807 - dense_3_loss: 1.4387 - dense_4_accuracy: 0.3000 - dense_1_accuracy: 0.3500 - dense_3_accuracy: 0.2000
# Epoch 12/50
# 2/2 [==============================] - 0s 52ms/step - loss: 4.2001 - dense_4_loss: 1.3832 - dense_1_loss: 1.4367 - dense_3_loss: 1.3802 - dense_4_accuracy: 0.2500 - dense_1_accuracy: 0.2500 - dense_3_accuracy: 0.3500
# Epoch 13/50
# 2/2 [==============================] - 0s 49ms/step - loss: 4.1486 - dense_4_loss: 1.3922 - dense_1_loss: 1.3846 - dense_3_loss: 1.3718 - dense_4_accuracy: 0.2750 - dense_1_accuracy: 0.3250 - dense_3_accuracy: 0.3000
# Epoch 14/50
# 2/2 [==============================] - 0s 229ms/step - loss: 4.1965 - dense_4_loss: 1.3858 - dense_1_loss: 1.4190 - dense_3_loss: 1.3916 - dense_4_accuracy: 0.2750 - dense_1_accuracy: 0.3250 - dense_3_accuracy: 0.2500
# Epoch 15/50
# 2/2 [==============================] - 0s 231ms/step - loss: 4.1220 - dense_4_loss: 1.3924 - dense_1_loss: 1.3905 - dense_3_loss: 1.3391 - dense_4_accuracy: 0.2250 - dense_1_accuracy: 0.2750 - dense_3_accuracy: 0.4250
# Epoch 16/50
# 2/2 [==============================] - 0s 50ms/step - loss: 4.0871 - dense_4_loss: 1.3660 - dense_1_loss: 1.3415 - dense_3_loss: 1.3796 - dense_4_accuracy: 0.3500 - dense_1_accuracy: 0.3750 - dense_3_accuracy: 0.3750
# Epoch 17/50
# 2/2 [==============================] - 0s 213ms/step - loss: 4.2625 - dense_4_loss: 1.3975 - dense_1_loss: 1.3801 - dense_3_loss: 1.4849 - dense_4_accuracy: 0.3000 - dense_1_accuracy: 0.3000 - dense_3_accuracy: 0.2000
# Epoch 18/50
# 2/2 [==============================] - 0s 50ms/step - loss: 4.2377 - dense_4_loss: 1.4039 - dense_1_loss: 1.3621 - dense_3_loss: 1.4718 - dense_4_accuracy: 0.2250 - dense_1_accuracy: 0.3250 - dense_3_accuracy: 0.2750
# Epoch 19/50
# 2/2 [==============================] - 0s 246ms/step - loss: 4.1423 - dense_4_loss: 1.3773 - dense_1_loss: 1.3693 - dense_3_loss: 1.3957 - dense_4_accuracy: 0.3500 - dense_1_accuracy: 0.2500 - dense_3_accuracy: 0.1750
# Epoch 20/50
# 2/2 [==============================] - 0s 50ms/step - loss: 4.1411 - dense_4_loss: 1.3759 - dense_1_loss: 1.3871 - dense_3_loss: 1.3780 - dense_4_accuracy: 0.2750 - dense_1_accuracy: 0.2750 - dense_3_accuracy: 0.2250
# Epoch 21/50
# 2/2 [==============================] - 0s 236ms/step - loss: 3.9691 - dense_4_loss: 1.3761 - dense_1_loss: 1.2127 - dense_3_loss: 1.3803 - dense_4_accuracy: 0.3000 - dense_1_accuracy: 0.4750 - dense_3_accuracy: 0.2250
# Epoch 22/50
# 2/2 [==============================] - 0s 236ms/step - loss: 3.9715 - dense_4_loss: 1.3744 - dense_1_loss: 1.2353 - dense_3_loss: 1.3617 - dense_4_accuracy: 0.2250 - dense_1_accuracy: 0.3500 - dense_3_accuracy: 0.3750
# Epoch 23/50
# 2/2 [==============================] - 0s 50ms/step - loss: 3.8471 - dense_4_loss: 1.3704 - dense_1_loss: 1.1308 - dense_3_loss: 1.3459 - dense_4_accuracy: 0.2500 - dense_1_accuracy: 0.6000 - dense_3_accuracy: 0.3500
# Epoch 24/50
# 2/2 [==============================] - 0s 50ms/step - loss: 3.8286 - dense_4_loss: 1.3463 - dense_1_loss: 1.1507 - dense_3_loss: 1.3316 - dense_4_accuracy: 0.3250 - dense_1_accuracy: 0.4500 - dense_3_accuracy: 0.2750
# Epoch 25/50
# 2/2 [==============================] - 0s 50ms/step - loss: 3.6309 - dense_4_loss: 1.2760 - dense_1_loss: 1.1023 - dense_3_loss: 1.2526 - dense_4_accuracy: 0.4000 - dense_1_accuracy: 0.4500 - dense_3_accuracy: 0.3500
# Epoch 26/50
# 2/2 [==============================] - 0s 50ms/step - loss: 5.4056 - dense_4_loss: 1.3995 - dense_1_loss: 2.5212 - dense_3_loss: 1.4849 - dense_4_accuracy: 0.3000 - dense_1_accuracy: 0.4750 - dense_3_accuracy: 0.3500
# Epoch 27/50
# 2/2 [==============================] - 0s 210ms/step - loss: 4.0619 - dense_4_loss: 1.3721 - dense_1_loss: 1.3089 - dense_3_loss: 1.3809 - dense_4_accuracy: 0.3000 - dense_1_accuracy: 0.2750 - dense_3_accuracy: 0.2500
# Epoch 28/50
# 2/2 [==============================] - 0s 245ms/step - loss: 4.2297 - dense_4_loss: 1.4281 - dense_1_loss: 1.4259 - dense_3_loss: 1.3757 - dense_4_accuracy: 0.3000 - dense_1_accuracy: 0.2500 - dense_3_accuracy: 0.3250
# Epoch 29/50
# 2/2 [==============================] - 0s 232ms/step - loss: 4.2883 - dense_4_loss: 1.4655 - dense_1_loss: 1.3932 - dense_3_loss: 1.4296 - dense_4_accuracy: 0.2500 - dense_1_accuracy: 0.3000 - dense_3_accuracy: 0.2250
# Epoch 30/50
# 2/2 [==============================] - 0s 236ms/step - loss: 4.1158 - dense_4_loss: 1.3849 - dense_1_loss: 1.3654 - dense_3_loss: 1.3656 - dense_4_accuracy: 0.2500 - dense_1_accuracy: 0.2750 - dense_3_accuracy: 0.3750
# Epoch 31/50
# 2/2 [==============================] - 0s 206ms/step - loss: 4.3198 - dense_4_loss: 1.3925 - dense_1_loss: 1.5642 - dense_3_loss: 1.3630 - dense_4_accuracy: 0.2500 - dense_1_accuracy: 0.2000 - dense_3_accuracy: 0.3750
# Epoch 32/50
# 2/2 [==============================] - 0s 50ms/step - loss: 4.1886 - dense_4_loss: 1.3921 - dense_1_loss: 1.4431 - dense_3_loss: 1.3535 - dense_4_accuracy: 0.2500 - dense_1_accuracy: 0.2500 - dense_3_accuracy: 0.4000
# Epoch 33/50
# 2/2 [==============================] - 0s 234ms/step - loss: 4.2475 - dense_4_loss: 1.3933 - dense_1_loss: 1.4276 - dense_3_loss: 1.4266 - dense_4_accuracy: 0.2500 - dense_1_accuracy: 0.2500 - dense_3_accuracy: 0.1500
# Epoch 34/50
# 2/2 [==============================] - 0s 51ms/step - loss: 4.1245 - dense_4_loss: 1.3927 - dense_1_loss: 1.3731 - dense_3_loss: 1.3587 - dense_4_accuracy: 0.2500 - dense_1_accuracy: 0.3000 - dense_3_accuracy: 0.4000
# Epoch 35/50
# 2/2 [==============================] - 0s 52ms/step - loss: 4.0919 - dense_4_loss: 1.3748 - dense_1_loss: 1.3809 - dense_3_loss: 1.3362 - dense_4_accuracy: 0.2500 - dense_1_accuracy: 0.4500 - dense_3_accuracy: 0.3500
# Epoch 36/50
# 2/2 [==============================] - 0s 232ms/step - loss: 4.3733 - dense_4_loss: 1.3764 - dense_1_loss: 1.4406 - dense_3_loss: 1.5563 - dense_4_accuracy: 0.3500 - dense_1_accuracy: 0.3000 - dense_3_accuracy: 0.2250
# Epoch 37/50
# 2/2 [==============================] - 0s 237ms/step - loss: 4.0875 - dense_4_loss: 1.3989 - dense_1_loss: 1.3398 - dense_3_loss: 1.3488 - dense_4_accuracy: 0.1750 - dense_1_accuracy: 0.2750 - dense_3_accuracy: 0.3000
# Epoch 38/50
# 2/2 [==============================] - 0s 53ms/step - loss: 4.1004 - dense_4_loss: 1.3950 - dense_1_loss: 1.3268 - dense_3_loss: 1.3786 - dense_4_accuracy: 0.2750 - dense_1_accuracy: 0.2750 - dense_3_accuracy: 0.2250
# Epoch 39/50
# 2/2 [==============================] - 0s 49ms/step - loss: 4.1009 - dense_4_loss: 1.3908 - dense_1_loss: 1.3447 - dense_3_loss: 1.3654 - dense_4_accuracy: 0.1750 - dense_1_accuracy: 0.2500 - dense_3_accuracy: 0.2250
# Epoch 40/50
# 2/2 [==============================] - 0s 250ms/step - loss: 4.0379 - dense_4_loss: 1.3902 - dense_1_loss: 1.2827 - dense_3_loss: 1.3650 - dense_4_accuracy: 0.2500 - dense_1_accuracy: 0.3250 - dense_3_accuracy: 0.2500
# Epoch 41/50
# 2/2 [==============================] - 0s 51ms/step - loss: 4.0567 - dense_4_loss: 1.3963 - dense_1_loss: 1.2727 - dense_3_loss: 1.3877 - dense_4_accuracy: 0.2500 - dense_1_accuracy: 0.3500 - dense_3_accuracy: 0.2500
# Epoch 42/50
# 2/2 [==============================] - 0s 52ms/step - loss: 4.0627 - dense_4_loss: 1.3764 - dense_1_loss: 1.3482 - dense_3_loss: 1.3381 - dense_4_accuracy: 0.2500 - dense_1_accuracy: 0.3750 - dense_3_accuracy: 0.3500
# Epoch 43/50
# 2/2 [==============================] - 0s 50ms/step - loss: 3.9824 - dense_4_loss: 1.3646 - dense_1_loss: 1.2555 - dense_3_loss: 1.3623 - dense_4_accuracy: 0.3500 - dense_1_accuracy: 0.3250 - dense_3_accuracy: 0.3250
# Epoch 44/50
# 2/2 [==============================] - 0s 232ms/step - loss: 4.1494 - dense_4_loss: 1.4040 - dense_1_loss: 1.4268 - dense_3_loss: 1.3186 - dense_4_accuracy: 0.2000 - dense_1_accuracy: 0.2500 - dense_3_accuracy: 0.2750
# Epoch 45/50
# 2/2 [==============================] - 0s 50ms/step - loss: 3.9971 - dense_4_loss: 1.3517 - dense_1_loss: 1.3008 - dense_3_loss: 1.3446 - dense_4_accuracy: 0.3250 - dense_1_accuracy: 0.3250 - dense_3_accuracy: 0.3500
# Epoch 46/50
# 2/2 [==============================] - 0s 252ms/step - loss: 4.0791 - dense_4_loss: 1.3817 - dense_1_loss: 1.3265 - dense_3_loss: 1.3710 - dense_4_accuracy: 0.2500 - dense_1_accuracy: 0.3750 - dense_3_accuracy: 0.2250
# Epoch 47/50
# 2/2 [==============================] - 0s 51ms/step - loss: 3.9692 - dense_4_loss: 1.3572 - dense_1_loss: 1.3018 - dense_3_loss: 1.3102 - dense_4_accuracy: 0.3500 - dense_1_accuracy: 0.5000 - dense_3_accuracy: 0.4000
# Epoch 48/50
# 2/2 [==============================] - 0s 239ms/step - loss: 5.1425 - dense_4_loss: 1.8559 - dense_1_loss: 1.3323 - dense_3_loss: 1.9544 - dense_4_accuracy: 0.2250 - dense_1_accuracy: 0.4250 - dense_3_accuracy: 0.2500
# Epoch 49/50
# 2/2 [==============================] - 0s 64ms/step - loss: 3.8117 - dense_4_loss: 1.3209 - dense_1_loss: 1.2137 - dense_3_loss: 1.2771 - dense_4_accuracy: 0.3500 - dense_1_accuracy: 0.4000 - dense_3_accuracy: 0.3500
# Epoch 50/50
# 2/2 [==============================] - 0s 246ms/step - loss: 4.0547 - dense_4_loss: 1.3897 - dense_1_loss: 1.3386 - dense_3_loss: 1.3264 - dense_4_accuracy: 0.2250 - dense_1_accuracy: 0.3500 - dense_3_accuracy: 0.3250

# %%
model.save('multiclassmodel.h5')

# %%
from keras.models import load_model
import numpy as np
from tensorflow.keras.preprocessing import image

# %%
test_image  = image.load_img('/content/drive/MyDrive/AI/CNN_train_test_img/th.jpg',target_size = (224,224))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)

# %%
#Load Model
model = load_model('multiclassmodel.h5')
result = model.predict(test_image)
print(result)
# Out:
# 1/1 [==============================] - 1s 1s/step
# [array([[0.2817376 , 0.22766456, 0.21678035, 0.2738175 ]], dtype=float32), array([[0.22668937, 0.20329714, 0.26935965, 0.3006539 ]], dtype=float32), array([[0.26623598, 0.18892294, 0.23310272, 0.31173837]], dtype=float32)]

# %%
result[0][0]
# Out:
# array([0.2817376 , 0.22766456, 0.21678035, 0.2738175 ], dtype=float32)

# %%
a = np.argmax(result[0])
print(a)
b = np.argmax(result[1])
print(b)
c= np.argmax(result[2])
print(c)
# Out:
# 0
# 3
# 3

# %%
import statistics

# %%
final_pred = statistics.mode((a,b,c))

# %%
if final_pred ==0:
  prediction = 'Messi'
  print(prediction)

elif final_pred==1:
  prediction = 'Modi'
  print(prediction)

elif final_pred==2:
  prediction = 'Ritik'
  print(prediction)  

elif final_pred==3:
  prediction = 'Virat'
  print(prediction)
# Out:
# Virat

# %% [markdown]
# Although the model is complicated to implement, the parameter number of the whole model is not large. The Dense layers always take a majority of parameters. Besides, the appearance of the global average pooling layers helps to reduce significantly the parameter number, thus reducing the computational complexity of the model.

# %% [markdown]
# **IV. Conclusion**
#
# We have discovered the architecture as well as the implementation of the GoogLeNet model on the Keras platform. It is composed of Inception blocks. Each block has a special architecture where it extracts simultaneously the input features through four parallel paths. Besides, the 1×1 convolutional layers are maximum applied in these paths to reduce channel dimensionality. Moreover, the application of the max-pooling layer between some Inception blocks plays a role in reducing the resolution, thus reducing the computational complexity. In summary, the parameter number of this model is 6x smaller than the Alexnet model and much smaller than the VGG model. Especially, it outperforms these models. This interesting architecture of GoogLeNet is also an inspiration for the appearance of later models.
#
# References:
#
# [1] Szegedy, Christian, et al. “Going deeper with convolutions.” Proceedings of the IEEE conference on computer vision and pattern recognition. 2015.

# %%
#End
